# %% [markdown]
# <a href="https://colab.research.google.com/github/ChandrikaRongala/AI_ML_Avanthi_Chandrika/blob/main/Day_5_pandas_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
#collection
#ask questions
#clean
#analysis
#sharing insights

# %%
dict = {'name':['sritha','chandu','chandrika','radha','krishna'], 'Gender':['f','m','f','f','m']}
df =pd.DataFrame(dict)
df
# Out:
#         name Gender
# 0     sritha      f
# 1     chandu      m
# 2  chandrika      f
# 3      radha      f
# 4    krishna      m

# %%
df[0:5]
# Out:
#         name Gender
# 0     sritha      f
# 1     chandu      m
# 2  chandrika      f
# 3      radha      f
# 4    krishna      m

# %%
df.loc[3]
# Out:
# name      radha
# Gender        f
# Name: 3, dtype: object

# %%
d = {'SNo':[1,2,3],
    'name':['chandu','krishna','radha'],
    'fav_color':['pink','blue','purple'],
    'food':['biriyani','chicken','panipuri'],
}
df =pd.DataFrame(d)
df.head()
# Out:
#    SNo     name fav_color      food
# 0    1   chandu      pink  biriyani
# 1    2  krishna      blue   chicken
# 2    3    radha    purple  panipuri

# %%
df =pd.read_excel('/content/pokemon_data.xlsx')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
#read each row
for index, row in df.iterrows():
  if row['Attack'] >70:
   print(index, row['Name'], row['Attack'])
# Out:
# 2 Venusaur 82
# 3 VenusaurMega Venusaur 100
# 6 Charizard 84
# 7 CharizardMega Charizard X 130
# 8 CharizardMega Charizard Y 104
# 11 Blastoise 83
# 12 BlastoiseMega Blastoise 103
# 18 Beedrill 90
# 19 BeedrillMega Beedrill 150
# 22 Pidgeot 80
# 23 PidgeotMega Pidgeot 80
# 25 Raticate 81
# 27 Fearow 90
# 29 Arbok 85
# 31 Raichu 90
# 32 Sandshrew 75
# 33 Sandslash 100
# 36 Nidoqueen 92
# 38 Nidorino 72
# 39 Nidoking 102
# 43 Ninetales 76
# 47 Golbat 80
# 50 Vileplume 80
# 52 Parasect 95
# 56 Dugtrio 80
# 60 Golduck 82
# 61 Mankey 80
# 62 Primeape 105
# 64 Arcanine 110
# 67 Poliwrath 95
# 72 Machop 80
# 73 Machoke 100
# 74 Machamp 130
# 75 Bellsprout 75
# 76 Weepinbell 90
# 77 Victreebel 105
# 80 Geodude 80
# 81 Graveler 95
# 82 Golem 120
# 83 Ponyta 85
# 84 Rapidash 100
# 86 Slowbro 75
# 87 SlowbroMega Slowbro 75
# 91 Doduo 85
# 92 Dodrio 110
# 95 Grimer 80
# 96 Muk 105
# 98 Cloyster 95
# 105 Hypno 73
# 106 Krabby 105
# 107 Kingler 130
# 111 Exeggutor 95
# 113 Marowak 80
# ...

# %%
#sorting
df.sort_values('Name',ascending=False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Gender','Name'], ascending= [1,0])
